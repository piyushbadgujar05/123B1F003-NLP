# %%
 import nltk #imported nltk library
nltk.download('punkt_tab') #Install the “punkt” tokenizer models needed for sentence and word tokenization
nltk.download('averaged_perceptron_tagger_eng') #initiates the download of the pre-trained English Part-of-Speech (POS) tagger model from NLTK's data repository
nltk.download('wordnet') #initiates the download of the WordNet lexical database from NLTK's data repository.
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
#Now we are doing tokenization first we have taken one small paragraph
paragraph="""Hello world good morning have a great day.A paragraph is a collection of sentences focused on a single main idea. Typically, effective paragraphs include aparagragh to introduce the central point, several supporting sentences for details, and a concluding sentence to summarize or transition"""

# %%
words=nltk.word_tokenize(paragraph) # word_tokenize() splits a sentence into words and punctuation marks as separate tokens.

print(words)# printing words
# Out:
# ['Hello', 'world', 'good', 'morning', 'have', 'a', 'great', 'day.A', 'paragraph', 'is', 'a', 'collection', 'of', 'sentences', 'focused', 'on', 'a', 'single', 'main', 'idea', '.', 'Typically', ',', 'effective', 'paragraphs', 'include', 'aparagragh', 'to', 'introduce', 'the', 'central', 'point', ',', 'several', 'supporting', 'sentences', 'for', 'details', ',', 'and', 'a', 'concluding', 'sentence', 'to', 'summarize', 'or', 'transition']

# %%
tagged=nltk.pos_tag(tokens) #This function takes a sequence of words (tokens) as input. It then processes the words in context and assigns a grammatical category (e.g., noun, verb, adjective) to each one.
print(tagged)
# Out:
# [('Hello', 'NNP'), ('world', 'NN'), ('good', 'JJ'), ('morning', 'NN'), ('have', 'VBP'), ('a', 'DT'), ('great', 'JJ'), ('day', 'NN'), ('sample', 'VB'), ('paragraph', 'IN'), ('A', 'DT'), ('paragraph', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('collection', 'NN'), ('of', 'IN'), ('sentences', 'NNS'), ('focused', 'VBN'), ('on', 'IN'), ('a', 'DT'), ('single', 'JJ'), ('main', 'JJ'), ('idea', 'NN'), ('.', '.'), ('Typically', 'RB'), (',', ','), ('effective', 'JJ'), ('paragraphs', 'NN'), ('include', 'VBP'), ('a', 'DT'), ('topic', 'JJ'), ('sentence', 'NN'), ('to', 'TO'), ('introduce', 'VB'), ('the', 'DT'), ('central', 'JJ'), ('point', 'NN'), (',', ','), ('several', 'JJ'), ('supporting', 'VBG'), ('sentences', 'NNS'), ('for', 'IN'), ('details', 'NNS'), (',', ','), ('and', 'CC'), ('a', 'DT'), ('concluding', 'VBG'), ('sentence', 'NN'), ('to', 'TO'), ('summarize', 'VB'), ('or', 'CC'), ('transition', 'NN')]

# %%
tokens1=nltk.sent_tokenize(paragraph) # sent_tokenize() splits a string into a list of sentences, handling punctuation and abbreviations.
print(tokens1)
# Out:
# ['Hello world good morning have a great day.A paragraph is a collection of sentences focused on a single main idea.', 'Typically, effective paragraphs include aparagragh to introduce the central point, several supporting sentences for details, and a concluding sentence to summarize or transition']

# %%
from nltk.stem import PorterStemmer  #Porter Stemmer algorithm, strips suffixes from words to reduce them to their base form for text analysis.
ps=PorterStemmer()
for word in words:
  print(word+"---->"+ps.stem(word))

# It often results in over-stemming, creating non-dictionary words (e.g., "morning" becomes "morn") because it follows crude heuristic rules rather than linguistic meaning.

# hence we use lemmatization
# Out:
# Hello---->hello
# world---->world
# good---->good
# morning---->morn
# have---->have
# a---->a
# great---->great
# day---->day
# sample---->sampl
# paragraph---->paragraph
# A---->a
# paragraph---->paragraph
# is---->is
# a---->a
# collection---->collect
# of---->of
# sentences---->sentenc
# focused---->focus
# on---->on
# a---->a
# single---->singl
# main---->main
# idea---->idea
# .---->.
# Typically---->typic
# ,---->,
# effective---->effect
# paragraphs---->paragraph
# include---->includ
# a---->a
# topic---->topic
# sentence---->sentenc
# to---->to
# introduce---->introduc
# the---->the
# central---->central
# point---->point
# ,---->,
# several---->sever
# supporting---->support
# sentences---->sentenc
# for---->for
# details---->detail
# ,---->,
# and---->and
# a---->a
# concluding---->conclud
# sentence---->sentenc
# to---->to
# summarize---->summar
# or---->or
# transition---->transit

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("better", pos="a"))
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
print(lemmatized_words)
# Out:
# good
# ['Hello', 'world', 'good', 'morning', 'have', 'a', 'great', 'day', 'sample', 'paragraph', 'A', 'paragraph', 'is', 'a', 'collection', 'of', 'sentence', 'focused', 'on', 'a', 'single', 'main', 'idea', '.', 'Typically', ',', 'effective', 'paragraph', 'include', 'a', 'topic', 'sentence', 'to', 'introduce', 'the', 'central', 'point', ',', 'several', 'supporting', 'sentence', 'for', 'detail', ',', 'and', 'a', 'concluding', 'sentence', 'to', 'summarize', 'or', 'transition']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]
print(filtered_words)
# Out:
# ['Hello', 'world', 'good', 'morning', 'great', 'day', 'sample', 'paragraph', 'paragraph', 'collection', 'sentences', 'focused', 'single', 'main', 'idea', '.', 'Typically', ',', 'effective', 'paragraphs', 'include', 'topic', 'sentence', 'introduce', 'central', 'point', ',', 'several', 'supporting', 'sentences', 'details', ',', 'concluding', 'sentence', 'summarize', 'transition']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
